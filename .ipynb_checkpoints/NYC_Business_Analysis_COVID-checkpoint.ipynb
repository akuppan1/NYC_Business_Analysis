# %%
import pandas as pd

# %%
df_nyc = pd.read_csv('Legally_Operating_Businesses.csv')
# Out:
# C:\Users\booos\anaconda3\envs\learn-env\lib\site-packages\IPython\core\interactiveshell.py:3145: DtypeWarning: Columns (19,20) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
df_nyc
# Out:
#        DCA License Number License Type License Expiration Date License Status  \
# 0             1412954-DCA   Individual              09/30/2012       Inactive
# 1             0967332-DCA     Business              02/28/2017       Inactive
# 2             1057563-DCA     Business              02/28/2023         Active
# 3             1108528-DCA   Individual              03/31/2004       Inactive
# 4             1400778-DCA   Individual              04/30/2014       Inactive
# ...                   ...          ...                     ...            ...
# 272244        1029195-DCA   Individual              12/31/2010       Inactive
# 272245        1466957-DCA   Individual              04/30/2014       Inactive
# 272246        1227004-DCA   Individual              09/30/2006       Inactive
# 272247        0796771-DCA   Individual              02/28/2004       Inactive
# 272248        1004519-DCA   Individual              10/31/2008       Inactive
#
# ...

# %%
df_nyc.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 272249 entries, 0 to 272248
# Data columns (total 27 columns):
#  #   Column                         Non-Null Count   Dtype
# ---  ------                         --------------   -----
#  0   DCA License Number             272249 non-null  object
#  1   License Type                   272249 non-null  object
#  2   License Expiration Date        251840 non-null  object
#  3   License Status                 272249 non-null  object
#  4   License Creation Date          272249 non-null  object
#  5   Industry                       272249 non-null  object
#  6   Business Name                  272190 non-null  object
#  7   Business Name 2                49639 non-null   object
#  8   Address Building               179442 non-null  object
#  9   Address Street Name            180510 non-null  object
#  10  Secondary Address Street Name  2524 non-null    object
#  11  Address City                   271441 non-null  object
# ...

# %%
df_nyc_1 = pd.read_csv('Legally_Operating_Businesses.csv', usecols=['License Creation Date','License Type', 'Industry', 'Address ZIP'])

# %%
df_nyc_1['License Creation Date'] = pd.to_datetime(df_nyc_1['License Creation Date'])

# %%
type(df_nyc_1['License Creation Date'][1])
# Out:
# pandas._libs.tslibs.timestamps.Timestamp

# %%
df_nyc_1 = df_nyc_1[df_nyc_1['License Creation Date'].dt.year > 1990]

# %%
df_nyc_1.sort_values(by='License Creation Date')
# Out:
#        License Type License Creation Date                     Industry  \
# 97173      Business            1993-12-02               Laundry Jobber
# 71537    Individual            1993-12-14             Tow Truck Driver
# 50265    Individual            1993-12-20             Tow Truck Driver
# 93637    Individual            1993-12-22             Tow Truck Driver
# 110548   Individual            1993-12-28             Tow Truck Driver
# ...             ...                   ...                          ...
# 240828     Business            2022-01-13  Home Improvement Contractor
# 240900     Business            2022-01-13                       Garage
# 240867     Business            2022-01-13  Home Improvement Contractor
# 241206   Individual            2022-01-13             Tow Truck Driver
# 240865     Business            2022-01-13  Home Improvement Contractor
#
#        Address ZIP
# 97173        11217
# 71537        10310
# 50265        10804
# 93637        11373
# ...

# %%
df_nyc_1['Industry'].value_counts()
# Out:
# Home Improvement Salesperson      41020
# Home Improvement Contractor       39808
# Tobacco Retail Dealer             39335
# Secondhand Dealer - General       16657
# Electronics Store                 14850
# General Vendor                     9945
# Tow Truck Driver                   9726
# Stoop Line Stand                   9509
# Sightseeing Guide                  7309
# Electronic & Appliance Service     7001
# Laundry                            6883
# Pedicab Driver                     6281
# Process Server Individual          6059
# Locksmith                          5113
# Debt Collection Agency             5100
# Laundries                          4947
# Laundry Jobber                     4368
# Sidewalk Cafe                      3830
# Ticket Seller                      3522
# Garage                             3425
# Electronic Cigarette Dealer        3398
# Secondhand Dealer - Auto           2865
# Dealer In Products                 2748
# ...

# %%
df_nyc_1['Address ZIP'].value_counts()
# Out:
# 11385    3479
# 11220    3260
# 11214    3252
# 11368    3060
# 11235    2869
#          ...
# 34601       1
# 76086       1
# 13492       1
# 94949       1
# 30907       1
# Name: Address ZIP, Length: 3998, dtype: int64

# %%
df_nyc_1['License Creation Date'].dt.year.value_counts(sort=False)
# Out:
# 1993        8
# 1994     1207
# 1995     1807
# 1996     2252
# 1997     2981
# 1998     2625
# 1999     2946
# 2000     8504
# 2001     6867
# 2002    10057
# 2003    14141
# 2004    11202
# 2005    11569
# 2006    13980
# 2007    13459
# 2008    12698
# 2009    13751
# 2010    13656
# 2011    14206
# 2012    14848
# 2013    14536
# 2014    12251
# 2015    12531
# 2016    12270
# 2017    14757
# 2018    14234
# 2019     9913
# 2020     3880
# 2021     4927
# 2022      175
# Name: License Creation Date, dtype: int64

# %%
df_nyc_1['License Creation Date'].dt.year.value_counts(sort=False).plot(kind='bar', title='NYC BUSINESS LICENSE CREATION PER YEAR')
# Out:
# <AxesSubplot:title={'center':'NYC BUSINESS LICENSE CREATION PER YEAR'}>
